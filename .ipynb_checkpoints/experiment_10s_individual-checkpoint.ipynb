# %%
import time
import glob

import numpy as np
import matplotlib.pyplot as plt
import scipy.signal
import tensorflow as tf

from tensorflow import keras
from keras.models import Sequential
from keras.models import load_model
from keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.layers import (
    Input,
    Conv1D,
    MaxPooling1D,
    Dropout,
    BatchNormalization,
    Activation,
    Add,
    Dense,
    GlobalAveragePooling1D,
)
import keras.backend as K
# from easydl import clear_output
from sklearn.utils import shuffle

# from get_representations import *

# 这次试验的思路是
# 第一步 数据处理 提取出ECG和对应标签，将5000降采样到2048，保存
# 第二步 对每个个体定义test，val，train数据集的部分，比例为0:9:1，个体的每条数据调整为10s，即4096个点，
# 第三步 导入PCLR预训练模型，学习率0.001，mse，耐心50，epoch400，训练
# 第四步 使用BHS等验证模型效果
# ……

# %%
def normalization(train,val):
    """对三个数据集统一归一化后，返回"""
    
    alldata = np.zeros((1,4096))
    alldata = np.vstack((alldata,train))
    alldata = np.vstack((alldata,val))
#     alldata = np.vstack((alldata,test))
    
#     归一化
    ma = alldata.max()
    mi = alldata.min()
    alldata = (alldata-mi)/(ma-mi)
    
    print(ma)
    print(mi)
    s1 = train.shape[0]
    s2 = val.shape[0]
#     s3 = test.shape[0]
     
#     return alldata[1:s1+1],alldata[s1+1:s1+s2+1],alldata[s1+s2+1:]
    return alldata[1:s1+1],alldata[s1+1:s1+s2+1]

# %%
def load(index):
#           (xxxx,4096)
    ecg = np.load('/data/drink/ECG/{}.npy'.format(index))
#           (xxxx,2)
    label = np.load('/data/drink/label/label{}.npy'.format(index))

    ECG10 = []
    for i in range(int(ecg.shape[0]/2)):
        ECG10.append(np.concatenate([ecg[2*i],ecg[2*i+1]]))

    LABEL4 = []
    for i in range(int(label.shape[0]/2)):
        LABEL4.append(np.concatenate([label[2*i],label[2*i+1]]))

    return shuffle(ECG10[1:],LABEL4[1:],random_state=666)
#     return ECG10[1:],LABEL4[1:]

# 22开始 22-25 和 1-7 是没有归一化训练的
index = 25
ecg,label = load(index)
ecg = np.array(ecg)
label = np.array(label)
# longth = ecg.shape[0]

# %%
train_longth = int(ecg.shape[0]/10)

ECG_train = ecg[:train_longth]
ECG_val = ecg[train_longth:]
LABEL_train = label[:train_longth]
LABEL_val = label[train_longth:]

ECG_train.shape
# Out:
# (119, 4096)

# %%
ECG_train,ECG_val = normalization(ECG_train,ECG_val)
ECG_val.max()
# ECG_train.shape
# Out:
# 1.9342930900688238
# 0.0
# 1.0

# %%
# np.where(ECG_train==ECG_train.max())

# %%
# # 检查
# plt.plot(ECG_train[10])
# ECG_train.max()

# %%
# ECG_train,LABEL_train = shuffle(ECG_train,LABEL_train)

# %%
# plt.plot(ECG_train[63], label='label') 
# plt.legend()

# %%
pclr = load_model('/home/ubuntu/ml4h/ml4h/model_zoo/PCLR/zml/PCLR_lead_I.h5')

length = 32
model = tf.keras.models.Sequential()
model.add(pclr) # 记得改模型名称
model.add(Dense(length*10,activation='relu'))
model.add(Dense(length*5,activation='relu'))
model.add(Dense(length,activation='relu'))
model.add(Dense(4)) # sbp dbp
model.layers[0].trainable = False
model.summary()

# monitor:监视参数，min_delta:小于此数认为不变化，mode:loss小好，acc大好，patience:n周期无提升则退出，restore_best_weights:取最优权重
earlyStop = EarlyStopping(monitor='val_loss', 
                          min_delta=0, 
                          patience=100,
                          mode='min', 
                          verbose=1, 
                          restore_best_weights = True)

length = 32
epoch=300
batch_size=8
lr = 0.001
tp='mse'
opt = keras.optimizers.Adam(learning_rate=lr)
model.compile(optimizer=opt, loss=tp)

model_name = '/data/drink/e_result/10/'+str(index)+'&320-160-32-4-{epoch:03d}-{val_loss:.2f}.h5'
checkpoint = ModelCheckpoint(filepath=model_name, 
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min', 
                             save_best_value=True,
                             initial_value_threshold=150)

callback_list = [earlyStop, checkpoint]
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  functional_1 (Functional)   (None, 320)               6383648
#
#  dense_12 (Dense)            (None, 320)               102720
#
#  dense_13 (Dense)            (None, 160)               51360
#
#  dense_14 (Dense)            (None, 32)                5152
#
#  dense_15 (Dense)            (None, 4)                 132
#
# =================================================================
# Total params: 6,543,012
# Trainable params: 159,364
# Non-trainable params: 6,383,648
# _________________________________________________________________

# %%
h = model.fit(ECG_train,LABEL_train, 
              validation_data=(ECG_val,LABEL_val), 
              epochs=epoch, 
              batch_size=batch_size, 
              shuffle=True, 
              verbose=1,
              callbacks=callback_list
             )
# Out:
# Epoch 1/300
# 15/15 [==============================] - ETA: 0s - loss: 9460.8418
# Epoch 00001: val_loss improved from inf to 3134.34131, saving model to /data/drink/e_result/10/25&320-160-32-4-001-3134.34.h5
# 15/15 [==============================] - 3s 98ms/step - loss: 9460.8418 - val_loss: 3134.3413
# Epoch 2/300
#  9/15 [=================>............] - ETA: 0s - loss: 1655.2039
# Epoch 00002: val_loss improved from 3134.34131 to 231.01755, saving model to /data/drink/e_result/10/25&320-160-32-4-002-231.02.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 1411.5260 - val_loss: 231.0175
# Epoch 3/300
#  9/15 [=================>............] - ETA: 0s - loss: 183.6273
# Epoch 00003: val_loss improved from 231.01755 to 135.06686, saving model to /data/drink/e_result/10/25&320-160-32-4-003-135.07.h5
# 15/15 [==============================] - 1s 70ms/step - loss: 205.4368 - val_loss: 135.0669
# Epoch 4/300
#  9/15 [=================>............] - ETA: 0s - loss: 141.6418
# Epoch 00004: val_loss improved from 135.06686 to 75.87073, saving model to /data/drink/e_result/10/25&320-160-32-4-004-75.87.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 125.3152 - val_loss: 75.8707
# Epoch 5/300
#  9/15 [=================>............] - ETA: 0s - loss: 97.4395
# Epoch 00005: val_loss improved from 75.87073 to 74.26444, saving model to /data/drink/e_result/10/25&320-160-32-4-005-74.26.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 92.8381 - val_loss: 74.2644
# Epoch 6/300
#  9/15 [=================>............] - ETA: 0s - loss: 96.1801
# Epoch 00006: val_loss improved from 74.26444 to 69.19459, saving model to /data/drink/e_result/10/25&320-160-32-4-006-69.19.h5
# 15/15 [==============================] - 1s 70ms/step - loss: 85.1300 - val_loss: 69.1946
# Epoch 7/300
#  9/15 [=================>............] - ETA: 0s - loss: 80.1017
# Epoch 00007: val_loss improved from 69.19459 to 68.98687, saving model to /data/drink/e_result/10/25&320-160-32-4-007-68.99.h5
# 15/15 [==============================] - 1s 70ms/step - loss: 81.5941 - val_loss: 68.9869
# Epoch 8/300
#  9/15 [=================>............] - ETA: 0s - loss: 92.6091
# Epoch 00008: val_loss improved from 68.98687 to 67.16491, saving model to /data/drink/e_result/10/25&320-160-32-4-008-67.16.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 80.8683 - val_loss: 67.1649
# Epoch 9/300
#  9/15 [=================>............] - ETA: 0s - loss: 81.2362
# Epoch 00009: val_loss did not improve from 67.16491
# 15/15 [==============================] - 1s 62ms/step - loss: 79.4720 - val_loss: 72.6124
# Epoch 10/300
#  9/15 [=================>............] - ETA: 0s - loss: 99.6050
# Epoch 00010: val_loss did not improve from 67.16491
# 15/15 [==============================] - 1s 62ms/step - loss: 94.5642 - val_loss: 76.0917
# Epoch 11/300
#  9/15 [=================>............] - ETA: 0s - loss: 86.2356
# Epoch 00011: val_loss did not improve from 67.16491
# 15/15 [==============================] - 1s 63ms/step - loss: 83.9643 - val_loss: 69.5392
# Epoch 12/300
#  9/15 [=================>............] - ETA: 0s - loss: 71.1970
# Epoch 00012: val_loss improved from 67.16491 to 64.49488, saving model to /data/drink/e_result/10/25&320-160-32-4-012-64.49.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 78.5592 - val_loss: 64.4949
# Epoch 13/300
#  9/15 [=================>............] - ETA: 0s - loss: 56.7949
# Epoch 00013: val_loss did not improve from 64.49488
# 15/15 [==============================] - 1s 62ms/step - loss: 70.8948 - val_loss: 72.0796
# Epoch 14/300
#  9/15 [=================>............] - ETA: 0s - loss: 78.4738
# Epoch 00014: val_loss improved from 64.49488 to 61.27123, saving model to /data/drink/e_result/10/25&320-160-32-4-014-61.27.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 77.1571 - val_loss: 61.2712
# Epoch 15/300
#  9/15 [=================>............] - ETA: 0s - loss: 64.4627
# Epoch 00015: val_loss improved from 61.27123 to 60.49090, saving model to /data/drink/e_result/10/25&320-160-32-4-015-60.49.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 69.2334 - val_loss: 60.4909
# Epoch 16/300
#  9/15 [=================>............] - ETA: 0s - loss: 71.2788
# Epoch 00016: val_loss did not improve from 60.49090
# 15/15 [==============================] - 1s 63ms/step - loss: 67.8869 - val_loss: 66.4875
# Epoch 17/300
#  9/15 [=================>............] - ETA: 0s - loss: 86.0210
# Epoch 00017: val_loss did not improve from 60.49090
# 15/15 [==============================] - 1s 63ms/step - loss: 73.4624 - val_loss: 73.9226
# Epoch 18/300
#  9/15 [=================>............] - ETA: 0s - loss: 60.7264
# Epoch 00018: val_loss improved from 60.49090 to 60.15818, saving model to /data/drink/e_result/10/25&320-160-32-4-018-60.16.h5
# 15/15 [==============================] - 1s 70ms/step - loss: 64.7535 - val_loss: 60.1582
# Epoch 19/300
#  9/15 [=================>............] - ETA: 0s - loss: 61.6409
# Epoch 00019: val_loss improved from 60.15818 to 56.09958, saving model to /data/drink/e_result/10/25&320-160-32-4-019-56.10.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 65.6696 - val_loss: 56.0996
# Epoch 20/300
#  9/15 [=================>............] - ETA: 0s - loss: 75.4479
# Epoch 00020: val_loss did not improve from 56.09958
# 15/15 [==============================] - 1s 62ms/step - loss: 61.8912 - val_loss: 65.3676
# Epoch 21/300
#  9/15 [=================>............] - ETA: 0s - loss: 71.4590
# Epoch 00021: val_loss did not improve from 56.09958
# 15/15 [==============================] - 1s 62ms/step - loss: 68.4288 - val_loss: 56.9321
# Epoch 22/300
#  9/15 [=================>............] - ETA: 0s - loss: 58.0498
# Epoch 00022: val_loss improved from 56.09958 to 53.82570, saving model to /data/drink/e_result/10/25&320-160-32-4-022-53.83.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 63.2984 - val_loss: 53.8257
# Epoch 23/300
#  9/15 [=================>............] - ETA: 0s - loss: 61.0046
# Epoch 00023: val_loss improved from 53.82570 to 52.35511, saving model to /data/drink/e_result/10/25&320-160-32-4-023-52.36.h5
# 15/15 [==============================] - 1s 70ms/step - loss: 60.5227 - val_loss: 52.3551
# Epoch 24/300
#  9/15 [=================>............] - ETA: 0s - loss: 58.3665
# Epoch 00024: val_loss improved from 52.35511 to 51.80031, saving model to /data/drink/e_result/10/25&320-160-32-4-024-51.80.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 57.2880 - val_loss: 51.8003
# Epoch 25/300
#  9/15 [=================>............] - ETA: 0s - loss: 52.2291
# Epoch 00025: val_loss did not improve from 51.80031
# 15/15 [==============================] - 1s 62ms/step - loss: 53.7799 - val_loss: 68.6854
# Epoch 26/300
#  9/15 [=================>............] - ETA: 0s - loss: 60.0503
# Epoch 00026: val_loss did not improve from 51.80031
# 15/15 [==============================] - 1s 63ms/step - loss: 61.0662 - val_loss: 54.3654
# Epoch 27/300
#  9/15 [=================>............] - ETA: 0s - loss: 59.1857
# Epoch 00027: val_loss did not improve from 51.80031
# 15/15 [==============================] - 1s 63ms/step - loss: 60.7349 - val_loss: 59.2294
# Epoch 28/300
#  9/15 [=================>............] - ETA: 0s - loss: 60.9992
# Epoch 00028: val_loss improved from 51.80031 to 48.25677, saving model to /data/drink/e_result/10/25&320-160-32-4-028-48.26.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 57.4971 - val_loss: 48.2568
# Epoch 29/300
#  9/15 [=================>............] - ETA: 0s - loss: 49.0879
# Epoch 00029: val_loss did not improve from 48.25677
# 15/15 [==============================] - 1s 62ms/step - loss: 52.0453 - val_loss: 52.6552
# Epoch 30/300
#  9/15 [=================>............] - ETA: 0s - loss: 54.1340
# Epoch 00030: val_loss did not improve from 48.25677
# 15/15 [==============================] - 1s 62ms/step - loss: 56.0917 - val_loss: 53.4775
# Epoch 31/300
#  9/15 [=================>............] - ETA: 0s - loss: 45.9320
# Epoch 00031: val_loss improved from 48.25677 to 45.54168, saving model to /data/drink/e_result/10/25&320-160-32-4-031-45.54.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 52.0623 - val_loss: 45.5417
# Epoch 32/300
#  9/15 [=================>............] - ETA: 0s - loss: 48.5596
# Epoch 00032: val_loss did not improve from 45.54168
# 15/15 [==============================] - 1s 62ms/step - loss: 47.1170 - val_loss: 51.1546
# Epoch 33/300
#  9/15 [=================>............] - ETA: 0s - loss: 47.3703
# Epoch 00033: val_loss improved from 45.54168 to 45.19568, saving model to /data/drink/e_result/10/25&320-160-32-4-033-45.20.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 48.0457 - val_loss: 45.1957
# Epoch 34/300
#  9/15 [=================>............] - ETA: 0s - loss: 37.8501
# Epoch 00034: val_loss improved from 45.19568 to 43.20024, saving model to /data/drink/e_result/10/25&320-160-32-4-034-43.20.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 43.7398 - val_loss: 43.2002
# Epoch 35/300
#  9/15 [=================>............] - ETA: 0s - loss: 36.1040
# Epoch 00035: val_loss did not improve from 43.20024
# 15/15 [==============================] - 1s 63ms/step - loss: 43.2744 - val_loss: 46.2524
# Epoch 36/300
#  9/15 [=================>............] - ETA: 0s - loss: 45.3763
# Epoch 00036: val_loss improved from 43.20024 to 41.76319, saving model to /data/drink/e_result/10/25&320-160-32-4-036-41.76.h5
# 15/15 [==============================] - 1s 70ms/step - loss: 45.0560 - val_loss: 41.7632
# Epoch 37/300
#  8/15 [===============>..............] - ETA: 0s - loss: 38.8017
# Epoch 00037: val_loss did not improve from 41.76319
# 15/15 [==============================] - 1s 62ms/step - loss: 39.4659 - val_loss: 42.9828
# Epoch 38/300
#  9/15 [=================>............] - ETA: 0s - loss: 43.7641
# Epoch 00038: val_loss did not improve from 41.76319
# 15/15 [==============================] - 1s 62ms/step - loss: 38.6621 - val_loss: 42.5293
# Epoch 39/300
#  9/15 [=================>............] - ETA: 0s - loss: 40.7685
# Epoch 00039: val_loss did not improve from 41.76319
# 15/15 [==============================] - 1s 62ms/step - loss: 49.0732 - val_loss: 51.6832
# Epoch 40/300
#  9/15 [=================>............] - ETA: 0s - loss: 46.7809
# Epoch 00040: val_loss improved from 41.76319 to 41.66668, saving model to /data/drink/e_result/10/25&320-160-32-4-040-41.67.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 41.5801 - val_loss: 41.6667
# Epoch 41/300
#  9/15 [=================>............] - ETA: 0s - loss: 30.3913
# Epoch 00041: val_loss improved from 41.66668 to 38.55820, saving model to /data/drink/e_result/10/25&320-160-32-4-041-38.56.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 36.5238 - val_loss: 38.5582
# Epoch 42/300
#  9/15 [=================>............] - ETA: 0s - loss: 33.4402
# Epoch 00042: val_loss did not improve from 38.55820
# 15/15 [==============================] - 1s 62ms/step - loss: 35.4773 - val_loss: 41.8111
# Epoch 43/300
#  9/15 [=================>............] - ETA: 0s - loss: 30.5181
# Epoch 00043: val_loss did not improve from 38.55820
# 15/15 [==============================] - 1s 62ms/step - loss: 34.9038 - val_loss: 38.7988
# Epoch 44/300
#  8/15 [===============>..............] - ETA: 0s - loss: 35.2864
# Epoch 00044: val_loss did not improve from 38.55820
# 15/15 [==============================] - 1s 62ms/step - loss: 36.2753 - val_loss: 43.4128
# Epoch 45/300
#  9/15 [=================>............] - ETA: 0s - loss: 48.9858
# Epoch 00045: val_loss did not improve from 38.55820
# 15/15 [==============================] - 1s 62ms/step - loss: 49.4409 - val_loss: 38.9276
# Epoch 46/300
#  9/15 [=================>............] - ETA: 0s - loss: 47.4522
# Epoch 00046: val_loss did not improve from 38.55820
# 15/15 [==============================] - 1s 62ms/step - loss: 50.5586 - val_loss: 56.0690
# Epoch 47/300
#  9/15 [=================>............] - ETA: 0s - loss: 43.6951
# Epoch 00047: val_loss improved from 38.55820 to 36.87802, saving model to /data/drink/e_result/10/25&320-160-32-4-047-36.88.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 39.4095 - val_loss: 36.8780
# Epoch 48/300
#  9/15 [=================>............] - ETA: 0s - loss: 30.7853
# Epoch 00048: val_loss did not improve from 36.87802
# 15/15 [==============================] - 1s 62ms/step - loss: 30.8734 - val_loss: 38.8050
# Epoch 49/300
#  9/15 [=================>............] - ETA: 0s - loss: 28.4555
# Epoch 00049: val_loss improved from 36.87802 to 35.20732, saving model to /data/drink/e_result/10/25&320-160-32-4-049-35.21.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 33.9476 - val_loss: 35.2073
# Epoch 50/300
#  9/15 [=================>............] - ETA: 0s - loss: 25.9508
# Epoch 00050: val_loss did not improve from 35.20732
# 15/15 [==============================] - 1s 62ms/step - loss: 31.5476 - val_loss: 40.7413
# Epoch 51/300
#  9/15 [=================>............] - ETA: 0s - loss: 32.5525
# Epoch 00051: val_loss did not improve from 35.20732
# 15/15 [==============================] - 1s 62ms/step - loss: 33.6823 - val_loss: 39.1223
# Epoch 52/300
#  9/15 [=================>............] - ETA: 0s - loss: 31.7944
# Epoch 00052: val_loss did not improve from 35.20732
# 15/15 [==============================] - 1s 62ms/step - loss: 33.0301 - val_loss: 35.2540
# Epoch 53/300
#  9/15 [=================>............] - ETA: 0s - loss: 29.4939
# Epoch 00053: val_loss improved from 35.20732 to 34.35880, saving model to /data/drink/e_result/10/25&320-160-32-4-053-34.36.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 29.7000 - val_loss: 34.3588
# Epoch 54/300
#  9/15 [=================>............] - ETA: 0s - loss: 27.4024
# Epoch 00054: val_loss improved from 34.35880 to 33.92374, saving model to /data/drink/e_result/10/25&320-160-32-4-054-33.92.h5
# 15/15 [==============================] - 1s 70ms/step - loss: 27.8314 - val_loss: 33.9237
# Epoch 55/300
#  9/15 [=================>............] - ETA: 0s - loss: 29.7364
# Epoch 00055: val_loss did not improve from 33.92374
# 15/15 [==============================] - 1s 62ms/step - loss: 30.0126 - val_loss: 34.8707
# Epoch 56/300
#  9/15 [=================>............] - ETA: 0s - loss: 27.8782
# Epoch 00056: val_loss did not improve from 33.92374
# 15/15 [==============================] - 1s 62ms/step - loss: 30.6851 - val_loss: 45.8399
# Epoch 57/300
#  9/15 [=================>............] - ETA: 0s - loss: 29.1023
# Epoch 00057: val_loss did not improve from 33.92374
# 15/15 [==============================] - 1s 62ms/step - loss: 31.5932 - val_loss: 38.6033
# Epoch 58/300
#  9/15 [=================>............] - ETA: 0s - loss: 28.5229
# Epoch 00058: val_loss improved from 33.92374 to 32.53108, saving model to /data/drink/e_result/10/25&320-160-32-4-058-32.53.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 29.8713 - val_loss: 32.5311
# Epoch 59/300
#  9/15 [=================>............] - ETA: 0s - loss: 21.7184
# Epoch 00059: val_loss did not improve from 32.53108
# 15/15 [==============================] - 1s 62ms/step - loss: 24.6895 - val_loss: 39.7858
# Epoch 60/300
#  9/15 [=================>............] - ETA: 0s - loss: 33.5809
# Epoch 00060: val_loss did not improve from 32.53108
# 15/15 [==============================] - 1s 63ms/step - loss: 31.0020 - val_loss: 34.6619
# Epoch 61/300
#  9/15 [=================>............] - ETA: 0s - loss: 26.8830
# Epoch 00061: val_loss did not improve from 32.53108
# 15/15 [==============================] - 1s 62ms/step - loss: 24.9189 - val_loss: 40.2501
# Epoch 62/300
#  9/15 [=================>............] - ETA: 0s - loss: 26.6614
# Epoch 00062: val_loss did not improve from 32.53108
# 15/15 [==============================] - 1s 62ms/step - loss: 26.1663 - val_loss: 32.6067
# Epoch 63/300
#  9/15 [=================>............] - ETA: 0s - loss: 28.0005
# Epoch 00063: val_loss improved from 32.53108 to 31.76204, saving model to /data/drink/e_result/10/25&320-160-32-4-063-31.76.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 23.1940 - val_loss: 31.7620
# Epoch 64/300
#  9/15 [=================>............] - ETA: 0s - loss: 26.3056
# Epoch 00064: val_loss did not improve from 31.76204
# 15/15 [==============================] - 1s 62ms/step - loss: 27.5722 - val_loss: 33.8539
# Epoch 65/300
#  9/15 [=================>............] - ETA: 0s - loss: 25.6853
# Epoch 00065: val_loss improved from 31.76204 to 31.75443, saving model to /data/drink/e_result/10/25&320-160-32-4-065-31.75.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 25.9151 - val_loss: 31.7544
# Epoch 66/300
#  8/15 [===============>..............] - ETA: 0s - loss: 21.4775
# Epoch 00066: val_loss did not improve from 31.75443
# 15/15 [==============================] - 1s 62ms/step - loss: 22.3982 - val_loss: 33.9807
# Epoch 67/300
#  9/15 [=================>............] - ETA: 0s - loss: 23.5677
# Epoch 00067: val_loss did not improve from 31.75443
# 15/15 [==============================] - 1s 63ms/step - loss: 25.1965 - val_loss: 35.2653
# Epoch 68/300
#  9/15 [=================>............] - ETA: 0s - loss: 20.9910
# Epoch 00068: val_loss improved from 31.75443 to 31.17384, saving model to /data/drink/e_result/10/25&320-160-32-4-068-31.17.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 23.5176 - val_loss: 31.1738
# Epoch 69/300
#  9/15 [=================>............] - ETA: 0s - loss: 22.9058
# Epoch 00069: val_loss did not improve from 31.17384
# 15/15 [==============================] - 1s 63ms/step - loss: 21.3902 - val_loss: 36.4268
# Epoch 70/300
#  9/15 [=================>............] - ETA: 0s - loss: 24.5675
# Epoch 00070: val_loss did not improve from 31.17384
# 15/15 [==============================] - 1s 62ms/step - loss: 26.7162 - val_loss: 37.5784
# Epoch 71/300
#  9/15 [=================>............] - ETA: 0s - loss: 26.2346
# Epoch 00071: val_loss did not improve from 31.17384
# 15/15 [==============================] - 1s 62ms/step - loss: 24.2353 - val_loss: 32.9800
# Epoch 72/300
#  9/15 [=================>............] - ETA: 0s - loss: 21.8009
# Epoch 00072: val_loss improved from 31.17384 to 30.48960, saving model to /data/drink/e_result/10/25&320-160-32-4-072-30.49.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 25.9710 - val_loss: 30.4896
# Epoch 73/300
#  9/15 [=================>............] - ETA: 0s - loss: 23.9886
# Epoch 00073: val_loss did not improve from 30.48960
# 15/15 [==============================] - 1s 62ms/step - loss: 23.0094 - val_loss: 31.7371
# Epoch 74/300
#  9/15 [=================>............] - ETA: 0s - loss: 22.3438
# Epoch 00074: val_loss did not improve from 30.48960
# 15/15 [==============================] - 1s 63ms/step - loss: 20.1080 - val_loss: 31.4249
# Epoch 75/300
#  9/15 [=================>............] - ETA: 0s - loss: 22.4184
# Epoch 00075: val_loss did not improve from 30.48960
# 15/15 [==============================] - 1s 63ms/step - loss: 22.5123 - val_loss: 40.9770
# Epoch 76/300
#  9/15 [=================>............] - ETA: 0s - loss: 20.0065
# Epoch 00076: val_loss did not improve from 30.48960
# 15/15 [==============================] - 1s 62ms/step - loss: 21.2014 - val_loss: 32.0761
# Epoch 77/300
#  9/15 [=================>............] - ETA: 0s - loss: 21.5979
# Epoch 00077: val_loss improved from 30.48960 to 30.00672, saving model to /data/drink/e_result/10/25&320-160-32-4-077-30.01.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 22.1594 - val_loss: 30.0067
# Epoch 78/300
#  9/15 [=================>............] - ETA: 0s - loss: 18.6374
# Epoch 00078: val_loss did not improve from 30.00672
# 15/15 [==============================] - 1s 62ms/step - loss: 19.7805 - val_loss: 43.0878
# Epoch 79/300
#  9/15 [=================>............] - ETA: 0s - loss: 27.1987
# Epoch 00079: val_loss did not improve from 30.00672
# 15/15 [==============================] - 1s 62ms/step - loss: 24.0407 - val_loss: 30.2997
# Epoch 80/300
#  9/15 [=================>............] - ETA: 0s - loss: 19.6986
# Epoch 00080: val_loss did not improve from 30.00672
# 15/15 [==============================] - 1s 62ms/step - loss: 18.4920 - val_loss: 38.7558
# Epoch 81/300
#  9/15 [=================>............] - ETA: 0s - loss: 27.9872
# Epoch 00081: val_loss did not improve from 30.00672
# 15/15 [==============================] - 1s 63ms/step - loss: 25.4194 - val_loss: 39.1321
# Epoch 82/300
#  9/15 [=================>............] - ETA: 0s - loss: 21.0810
# Epoch 00082: val_loss improved from 30.00672 to 29.60243, saving model to /data/drink/e_result/10/25&320-160-32-4-082-29.60.h5
# 15/15 [==============================] - 1s 70ms/step - loss: 19.4745 - val_loss: 29.6024
# Epoch 83/300
#  9/15 [=================>............] - ETA: 0s - loss: 19.0360
# Epoch 00083: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 62ms/step - loss: 19.3123 - val_loss: 31.9881
# Epoch 84/300
#  9/15 [=================>............] - ETA: 0s - loss: 19.7093
# Epoch 00084: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 62ms/step - loss: 17.1511 - val_loss: 31.1341
# Epoch 85/300
#  9/15 [=================>............] - ETA: 0s - loss: 20.6589
# Epoch 00085: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 62ms/step - loss: 22.3917 - val_loss: 35.9939
# Epoch 86/300
#  9/15 [=================>............] - ETA: 0s - loss: 20.4354
# Epoch 00086: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 62ms/step - loss: 20.0231 - val_loss: 33.3175
# Epoch 87/300
#  9/15 [=================>............] - ETA: 0s - loss: 18.8764
# Epoch 00087: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 62ms/step - loss: 17.1652 - val_loss: 30.5653
# Epoch 88/300
#  9/15 [=================>............] - ETA: 0s - loss: 19.5742
# Epoch 00088: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 63ms/step - loss: 18.0710 - val_loss: 37.2098
# Epoch 89/300
#  9/15 [=================>............] - ETA: 0s - loss: 18.8152
# Epoch 00089: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 63ms/step - loss: 17.8514 - val_loss: 31.7635
# Epoch 90/300
#  9/15 [=================>............] - ETA: 0s - loss: 18.8753
# Epoch 00090: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 63ms/step - loss: 17.7050 - val_loss: 32.4953
# Epoch 91/300
#  9/15 [=================>............] - ETA: 0s - loss: 18.3141
# Epoch 00091: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 63ms/step - loss: 20.2569 - val_loss: 40.2563
# Epoch 92/300
#  9/15 [=================>............] - ETA: 0s - loss: 20.7405
# Epoch 00092: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 63ms/step - loss: 22.8176 - val_loss: 45.7459
# Epoch 93/300
#  9/15 [=================>............] - ETA: 0s - loss: 22.2010
# Epoch 00093: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 63ms/step - loss: 23.0651 - val_loss: 35.6666
# Epoch 94/300
#  9/15 [=================>............] - ETA: 0s - loss: 16.2868
# Epoch 00094: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 62ms/step - loss: 17.7398 - val_loss: 40.3967
# Epoch 95/300
#  9/15 [=================>............] - ETA: 0s - loss: 17.2210
# Epoch 00095: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 62ms/step - loss: 18.1028 - val_loss: 30.0742
# Epoch 96/300
#  9/15 [=================>............] - ETA: 0s - loss: 15.5860
# Epoch 00096: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 62ms/step - loss: 16.5646 - val_loss: 37.9289
# Epoch 97/300
#  9/15 [=================>............] - ETA: 0s - loss: 15.7009
# Epoch 00097: val_loss did not improve from 29.60243
# 15/15 [==============================] - 1s 62ms/step - loss: 16.7205 - val_loss: 31.0238
# Epoch 98/300
#  9/15 [=================>............] - ETA: 0s - loss: 18.7823
# Epoch 00098: val_loss improved from 29.60243 to 29.32123, saving model to /data/drink/e_result/10/25&320-160-32-4-098-29.32.h5
# 15/15 [==============================] - 1s 69ms/step - loss: 15.7737 - val_loss: 29.3212
# Epoch 99/300
#  8/15 [===============>..............] - ETA: 0s - loss: 19.8839
# Epoch 00099: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 63ms/step - loss: 16.6507 - val_loss: 31.0624
# Epoch 100/300
#  9/15 [=================>............] - ETA: 0s - loss: 25.8143
# Epoch 00100: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 62ms/step - loss: 25.2290 - val_loss: 47.2490
# Epoch 101/300
#  9/15 [=================>............] - ETA: 0s - loss: 15.5880
# Epoch 00101: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 62ms/step - loss: 15.9708 - val_loss: 29.3693
# Epoch 102/300
#  9/15 [=================>............] - ETA: 0s - loss: 11.5061
# Epoch 00102: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 63ms/step - loss: 13.7194 - val_loss: 29.6262
# Epoch 103/300
#  9/15 [=================>............] - ETA: 0s - loss: 17.0837
# Epoch 00103: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 62ms/step - loss: 14.9975 - val_loss: 30.0820
# Epoch 104/300
#  9/15 [=================>............] - ETA: 0s - loss: 13.9670
# Epoch 00104: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 62ms/step - loss: 14.7690 - val_loss: 32.2598
# Epoch 105/300
#  9/15 [=================>............] - ETA: 0s - loss: 12.2961
# Epoch 00105: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 62ms/step - loss: 14.9285 - val_loss: 30.6455
# Epoch 106/300
#  9/15 [=================>............] - ETA: 0s - loss: 15.8214
# Epoch 00106: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 62ms/step - loss:
val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 62ms/step - loss: 22.7312 - val_loss: 33.2656
# Epoch 197/300
#  9/15 [=================>............] - ETA: 0s - loss: 12.2332
# Epoch 00197: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 62ms/step - loss: 12.2688 - val_loss: 43.8662
# Epoch 198/300
#  9/15 [=================>............] - ETA: 0s - loss: 10.6025Restoring model weights from the end of the best epoch: 98.
#
# Epoch 00198: val_loss did not improve from 29.32123
# 15/15 [==============================] - 1s 64ms/step - loss: 9.4969 - val_loss: 31.7678
# Epoch 00198: early stopping

# %%
history = h.history
print(history.keys())
epochs = range(len(history['loss']))

plt.figure(figsize=(20, 5))
ax = plt.subplot(1, 2, 1)
ax.set_title('Train and Valid loss (mse)')
plt.plot(epochs[10:], history['val_loss'][10:], 'b', label='val_loss')
plt.plot(epochs[10:], history['loss'][10:], 'r', label='loss')
plt.savefig('./img/{index} loss.png'.format(index=index))
plt.legend()
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
#  # 验证

# %%
m = load_model('/data/drink/e_result/10/13&320-160-32-4-172-21.18.h5')
index = 13
# 18  25

# %%
def load(index):
#           (xxxx,4096)
    ecg = np.load('/data/drink/ECG/{}.npy'.format(index))
#           (xxxx,2)
    label = np.load('/data/drink/label/label{}.npy'.format(index))

    ECG10 = []
    for i in range(int(ecg.shape[0]/2)):
        ECG10.append(np.concatenate([ecg[2*i],ecg[2*i+1]]))

    LABEL4 = []
    for i in range(int(label.shape[0]/2)):
        LABEL4.append(np.concatenate([label[2*i],label[2*i+1]]))

#     return shuffle(ECG10[1:],LABEL4[1:],random_state=666)
    return ECG10[1:],LABEL4[1:]
# 22开始

ecg,label = load(index)
ecg = np.array(ecg)
label = np.array(label)
val_longth = ecg.shape[0]-int(ecg.shape[0]/10)


train_longth = int(ecg.shape[0]/10)
ECG_train = ecg[:train_longth]
ECG_val = ecg[train_longth:]
LABEL_train = label[:train_longth]
LABEL_val = label[train_longth:]

ECG_train.shape

ECG_train,ECG_val = normalization(ECG_train,ECG_val)
# Out:
# 1.6886876118771665
# 0.0

# %%
res = m.predict(ECG_val)
# print(res[0])
# print(LABEL_val[0])
# print(res.shape)

# %%
# 时序图 需要把10s的标签展开成5s的
def unfold(d2array,tp=0):
#     tp=0 提取dbp，tp=1提取sbp
    r = []
    for i in d2array:
        r.append(i[0 if tp else 1])
        r.append(i[2 if tp else 3])
    return r

res_d = unfold(res,0)
res_s = unfold(res,1)
lab_d = unfold(LABEL_val,0)
lab_s = unfold(LABEL_val,1)
    
plt.figure(figsize=(10, 5))
plt.title('Compare of True & Predict')
plt.plot(res_s[0:200], 'r', label='Predict SBP')
plt.plot(lab_s[0:200], 'orange', label='True SBP')
plt.plot(res_d[0:200], 'b', label='Predict DBP')
plt.plot(lab_d[0:200], 'skyblue', label='True DBP')
plt.xlabel('time(5s)/labels')
plt.ylabel('BP(mmHg)')
plt.legend(loc=1)
plt.savefig("./img/compare/Compare{:0>2d}.png".format(index))

# plt.plot(res[2], 'm', label='Predict DBP')
# plt.plot(res[3], 'g', label='True DBP')

# %%
# 偏差分布图
differ = abs(res-LABEL_val)

bias_d = unfold(differ,0)
bias_s = unfold(differ,1)
# lab_d = unfold(LABEL_val,0)
# lab_s = unfold(LABEL_val,1)

plt.title('Bias Distribution(sum of label groups='+str(val_longth*2)+')')
# plt.text(30,100 , 'sum='+str(val_longth), fontdict=None)
sth = plt.hist([bias_d,bias_s],
         label=['DBP','SBP'],
#          color=['indianred','lightcoral','deepskyblue','skyblue'],
#          cplor=['indianred']
#          histtype='barstacked'
        )
# 获取x坐标，换掉
j = 0
x_ticks = []
for i in sth[1]:
    x_ticks.append(round((i+j)/2,1))
    j=i

plt.xticks(x_ticks[1:])
plt.xlabel('bias(mmHg)')
plt.ylabel('amount of label groups')
plt.legend(loc=1)
plt.savefig("./img/distribution/Bias Distribution({longth}){index:0>2d}.png".format(index=index,longth=val_longth*2))

# %%
all_res = []
all_lab = []
all_res.append(np.concatenate([res_s,res_d]))
all_lab.append(np.concatenate([lab_s,lab_d]))
all_lab
# Out:
# [array([122.00690127, 123.90854721, 124.3224424 , ...,  86.48909165,
#          87.23872603,  87.48826066])]

# %%
x = np.array([])
for i in all_lab:
    x = np.hstack((x,i))


y = np.array([])
for j in all_res:
    y = np.hstack((y,j))
    
print(y.shape)
print(x.shape)
# Out:
# (5208,)
# (5208,)

# %%
# all_res.pop()
# all_lab.pop()

# %%
# BA图
import pyCompare
pyCompare.blandAltman(x,
                      y, 
                      percentage=False, 
                      title='Bland-Altman Plot',
#                       savePath='./img/SavedFigure1-25.png',
                      limitOfAgreement=1.96)

# %%
def BHS_standard(predict, test):
    total = len(predict[0])
    mm5 = np.sum(np.abs(predict-test)<=5.0)
    mm10 = np.sum(np.abs(predict-test)<=10.0)
    mm15 = np.sum(np.abs(predict-test)<=15.0)
    return total, mm5, mm10, mm15

# t_data = tf.transpose(test_label,(1,0))
# predict_data = tf.transpose(res,(1,0))
# predict_data.dtype # 检查数据类型，发现predict是float32，label是float64
# predict_data = tf.cast(predict_data,dtype='float64') 

total, mm5, mm10, mm15 = BHS_standard(np.array(all_res),np.array(all_lab))
print(total)
# Out:
# 5208

# %%
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5,mm10,mm15,total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%',mm10/total*100, '%',mm15/total*100, '%', total))
# Out:
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 3996            5065           5179          5208
# 76.728%        97.254%       99.443%         5208

# %%
def AAMI_standard(predict, test):
    total = len(predict[0])
    ME = np.mean(predict - test)
    MAE = np.mean(np.abs(predict-test))
    SD = np.std(predict-test)
    return total, ME, MAE, SD

def AAMI(res,test):
    total, ME, MAE, SD = AAMI_standard(res, test)
    print()
    print('-------------AAMI standard------------')
    print('ME            MAE         SD          total')
    print('%.3f        %.3f       %.3f       %d'%(ME,MAE,SD,total))
    
    return total, ME, MAE, SD

AAMI(np.array(all_res),np.array(all_lab)) #SBP
# Out:
# -------------AAMI standard------------
# ME            MAE         SD          total
# -0.614        3.395       4.412       5208
# (5208, -0.6144144788066909, 3.394570275624107, 4.4115935572751015)
