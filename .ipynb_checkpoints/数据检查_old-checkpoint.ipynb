# %%
import numpy as np
import time
import glob

import tensorflow as tf
import matplotlib.pyplot as plt

def load_data(tp:str):
    """
    tp: test or train
    return: array (n,m)
    """
    ECG = []
    for x in glob.glob('/home/ubuntu/data/Exercise/{tp}/sub_*.npz'.format(tp=tp)):
        data = np.load(x)
        data = data['arr_0']
        data = tf.transpose(data,(0,2,1))
        ECG.append(data)
#         for i in range(int(data.shape[0]/2)):
#             ECG.append(np.concatenate([data[i][0],data[2*i+1][0]]))
    print("finish loading data")
    return np.array(ECG)

# %%
data = load_data('val')
# Out:
# 2022-10-25 23:47:47.489016: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-25 23:47:47.525274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-25 23:47:47.525509: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-25 23:47:47.526599: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# ...

# %%
data[1].shape

# %%
x=1000
for i in range(0,2,2):
    plt.plot(np.concatenate([data[1][i+118+x][0], data[1][i+115+x][0]]))
